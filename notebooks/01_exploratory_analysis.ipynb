# %% [markdown]
# # Analise exploratoria
#
# Este notebook e auxiliar. A reproducao oficial usa `python scripts/run_all.py`.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
measures = pd.read_csv(ROOT / 'data' / 'processed' / 'realized_measures.csv')
measures.head()
